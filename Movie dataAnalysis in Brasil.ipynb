# %% [markdown]
# # Movie data analysis exibed in Brasil from 2009 at 2019
# Based in movies (https://oca.ancine.gov.br/cinema)
# Archive : 2120.xlsx

# %%
import pandas as pd
import numpy as npy
import seaborn as sd
# %matplotlib inline

# %%
data = pd.read_excel('2120.xlsx')
data.head()
# Out:
#   Listagem de Filmes Brasileiros e Estrangeiros Exibidos - 2009 a 2019  \
# 0                                                NaN
# 1                                    Ano de exibição
# 2                                               2019
# 3                                               2019
# 4                                               2019
#
#                   Unnamed: 1      Unnamed: 2 Unnamed: 3  \
# 0                        NaN             NaN        NaN
# 1             Título da obra         CPB/ROE     Gênero
# 2  120 Batimentos Por Minuto  E1700453800000     Ficção
# 3                    3 Faces  E1800494900000     Ficção
# 4           45 Dias Sem Você  B1800586000000     Ficção
#
#                       Unnamed: 4             Unnamed: 5          Unnamed: 6  \
# 0                            NaN                    NaN                 NaN
# 1  País(es) produtor(es) da obra  Nacionalidade da obra  Data de lançamento
# ...

# %% [markdown]
# # The command "skiprows = 2" jump the two first lines with errors

# %%
data = pd.read_excel('2120.xlsx', skiprows=2)
data.head()
# Out:
#   Ano de exibição              Título da obra         CPB/ROE    Gênero  \
# 0            2019   120 Batimentos Por Minuto  E1700453800000    Ficção
# 1            2019                     3 Faces  E1800494900000    Ficção
# 2            2019            45 Dias Sem Você  B1800586000000    Ficção
# 3            2019    A 100 Passos De Um Sonho  E1402795100000    Ficção
# 4            2019  A Abelhinha Maya - O Filme  E1800136100000  Animação
#
#   País(es) produtor(es) da obra Nacionalidade da obra Data de lançamento  \
# 0                        França           Estrangeira              43104
# 1                           Irã           Estrangeira              43559
# 2                        Brasil            Brasileira              43601
# 3                Estados Unidos           Estrangeira              41879
# 4                      Alemanha           Estrangeira              43237
#
#   Empresa distribuidora Origem da empresa distribuidora  \
# ...

# %% [markdown]
# # Lines with errors from tables. So, in the celula bellow, will be used a command for to delete these lines with errors.

# %%
data.tail(40)
# Out:
#                                         Ano de exibição  \
# 7061                                               2009
# 7062                                               2009
# 7063                                               2009
# 7064                                               2009
# 7065                                               2009
# 7066                                               2009
# 7067                                               2009
# 7068                                               2009
# 7069                                               2009
# 7070                                               2009
# 7071                                               2009
# 7072                                               2009
# 7073                                               2009
# 7074                                               2009
# 7075                                               2009
# 7076                                               2009
# ...

# %%
data = pd.read_excel('2120.xlsx', skiprows=2, skipfooter=20)
data.tail(40)
# Out:
#       Ano de exibição                       Título da obra         CPB/ROE  \
# 7041             2009                Um Romance de Geração  B0901019900000
# 7042             2009                Um Segredo em Família  E1600636100000
# 7043             2009                 Um Segredo entre Nós  E1600541700000
# 7044             2009             Um Taxi para a Escuridão  E1600546200000
# 7045             2009                   Uma Canção de Amor  E1600634200000
# 7046             2009          Uma Garota Dividida em dois  E1600549000000
# 7047             2009                 Uma Noite no Museu 2  E1500204900000
# 7048             2009                    Uma Prova de Amor  E1402591100000
# 7049             2009                  Uma Vida sem Regras  E1600589400000
# 7050             2009                 Up - Altas Aventuras  E1500587900000
# 7051             2009                     Valsa com Bashir  E1500883100000
# ...

# %% [markdown]
# # Showing the columns name

# %%
data.columns
# Out:
# Index(['Ano de exibição', 'Título da obra', 'CPB/ROE', 'Gênero',
#        'País(es) produtor(es) da obra', 'Nacionalidade da obra',
#        'Data de lançamento', 'Empresa distribuidora',
#        'Origem da empresa distribuidora', 'Público no ano de exibição',
#        'Renda (R$) no ano de exibição'],
#       dtype='object')

# %% [markdown]
# # Change the column name

# %%
data.rename(columns={'País(es) produtor(es) da obra': 'País','Título da obra':'Título','Ano de exibição':'Ano'})
# Out:
#        Ano                      Título         CPB/ROE        Gênero  \
# 0     2019   120 Batimentos Por Minuto  E1700453800000        Ficção
# 1     2019                     3 Faces  E1800494900000        Ficção
# 2     2019            45 Dias Sem Você  B1800586000000        Ficção
# 3     2019    A 100 Passos De Um Sonho  E1402795100000        Ficção
# 4     2019  A Abelhinha Maya - O Filme  E1800136100000      Animação
# ...    ...                         ...             ...           ...
# 7076  2009                 Xuxa Gêmeas  B0600616500000        Ficção
# 7077  2009                Zico na Rede  B0901041400000  Documentário
# 7078  2009                    À Deriva  B0901015000000        Ficção
# 7079  2009            É Proibido Fumar  B0901108700000        Ficção
# 7080  2009         Última Parada - 174  B0800914800000        Ficção
#
#                         País Nacionalidade da obra Data de lançamento  \
# ...

# %% [markdown]
# # Filtering and getting the cities located in the (País(es) produtor(es) da obra) columns.... under development

# %%
#data['País(es) produtor(es) da obra']
#data['País(es) produtor(es) da obra'].str.contains('')

for i in range(1):

    #l.append(int(input('Digite um numero: ')))
    
        data['País(es) produtor(es) da obra'].str.contains('') == data[data['País(es) produtor(es) da obra']==i].str.contains('')
        VResult[i]=data['País(es) produtor(es) da obra'].str.contains('')
        a=a+1
        
    
print(data[VResult])
print('quantidade:'+[a])
